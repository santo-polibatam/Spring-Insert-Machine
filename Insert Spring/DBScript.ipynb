-- %% [markdown]
-- # [dbo].[Logging]

-- %%
USE [sch]
GO

-- %%
/****** Object:  Table [dbo].[Logging]    Script Date: 8/29/2021 23:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Logging](
	[ID] [numeric](18, 0) NOT NULL,
	[Date Time] [datetime] NULL,
	[Sida A Missing spring] [nchar](10) NULL,
	[Sida A Not proper insert Leg locking] [nchar](10) NULL,
	[Side A Broke leg locking] [nchar](10) NULL,
	[Sida B Missing spring] [nchar](10) NULL,
	[Sida B Not proper insert Leg locking] [nchar](10) NULL,
	[Side B Broke leg locking] [nchar](10) NULL,
	[Result] [nchar](10) NULL,
 CONSTRAINT [PK_Logging] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Login_User]

-- %%
/****** Object:  Table [dbo].[Login_User]    Script Date: 8/29/2021 23:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Login_User](
	[User_ID] [nvarchar](50) NULL,
	[Password] [nvarchar](50) NULL,
	[Level_Scurity] [nvarchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Performance]

-- %%
/****** Object:  Table [dbo].[Performance]    Script Date: 8/29/2021 23:07:20 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Performance](
	[Pass] [nchar](10) NULL,
	[Fail] [nchar](10) NULL,
	[FP_Yield] [nchar](10) NULL
) ON [PRIMARY]
GO
